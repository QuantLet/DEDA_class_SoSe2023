# %%
import pandas as pd
import numpy as np
import math
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tools.sm_exceptions import ValueWarning, HessianInversionWarning, ConvergenceWarning
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %%
df = pd.read_csv("datasets/data.csv")

# %%
df.head()
# Out:
#     Open time      Open      High       Low     Close        Volume  \
# 0  2018-01-01  13715.65  13818.55  12750.00  13380.00   8609.915844
# 1  2018-01-02  13382.16  15473.49  12890.02  14675.11  20078.092111
# 2  2018-01-03  14690.00  15307.56  14150.00  14919.51  15905.667639
# 3  2018-01-04  14919.51  15280.00  13918.04  15059.54  21329.649574
# 4  2018-01-05  15059.56  17176.24  14600.00  16960.39  23251.491125
#
#                 Close time  Quote asset volume  Number of trades  \
# 0  2018-01-01 23:59:59.999        1.147997e+08            105595
# 1  2018-01-02 23:59:59.999        2.797171e+08            177728
# 2  2018-01-03 23:59:59.999        2.361169e+08            162787
# 3  2018-01-04 23:59:59.999        3.127816e+08            170310
# 4  2018-01-05 23:59:59.999        3.693220e+08            192969
#
#    Taker buy base asset volume  Taker buy quote asset volume  Ignore  year
# 0                  3961.938946                  5.280975e+07       0  2018
# 1                 11346.326739                  1.580801e+08       0  2018
# 2                  8994.953566                  1.335873e+08       0  2018
# 3                 12680.812951                  1.861168e+08       0  2018
# 4                 13346.622293                  2.118299e+08       0  2018

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Open time                     1994 non-null   object
#  1   Open                          1994 non-null   float64
#  2   High                          1994 non-null   float64
#  3   Low                           1994 non-null   float64
#  4   Close                         1994 non-null   float64
#  5   Volume                        1994 non-null   float64
#  6   Close time                    1994 non-null   object
#  7   Quote asset volume            1994 non-null   float64
#  8   Number of trades              1994 non-null   int64
#  9   Taker buy base asset volume   1994 non-null   float64
#  10  Taker buy quote asset volume  1994 non-null   float64
#  11  Ignore                        1994 non-null   int64
#  12  year                          1994 non-null   int64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 202.6+ KB

# %%
df["Close time"] = pd.to_datetime(df["Close time"], unit = "ns")
df["Close time"] = df["Close time"].dt.date

# %%
df = df.set_index(df["Close time"])

# %% [markdown]
# ### We are interested in `Close Price`

# %%
plt.figure(figsize = (16, 8))
plt.title("Bitcoin Price History")
plt.plot(df["Close"])
plt.xlabel("Date", fontsize = 18)
plt.ylabel("Close Price USD ($)", fontsize = 18)
plt.savefig('history.png', dpi=300)
plt.show()

# %%
returns = df["Close"].pct_change().dropna().values

# %%
plt.figure(figsize = (12, 8))
plt.title("Bitcoin returns history")
plt.plot(returns)
plt.xlabel("Date", fontsize = 18)
plt.ylabel("Returns", fontsize = 18)
plt.savefig('returns_history.png', dpi=300)
plt.show()

# %%
returns
# Out:
# array([0.09679447, 0.01665405, 0.0093857 , ..., 0.01869941, 0.02916227,
#        0.00754906])

# %%
plot_acf(returns)
plt.show()

# %%
plot_pacf(returns)
plt.show()
# Out:
# C:\Users\kaleem\AppData\Roaming\Python\Python310\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
plot_acf(df["Close"])
plt.show()

# %%
data = df.filter(["Close"])
dataset = data.values
# Get the number of rows to train the model
training_data_len = math.ceil(len(dataset) * .8)
training_data_len
# Out:
# 1596

# %%
# Scale the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.15810341],
#        [0.17824067],
#        [0.18204077],
#        ...,
#        [0.34808489],
#        [0.35969214],
#        [0.36278447]])

# %% [markdown]
# ### Feature Selection and Training

# %%
num_features = 80
# Create the scaled training dataset
train_data = scaled_data[0: training_data_len, :]
# Split the data into train and test sets
X_train = []
y_train = []

for i in range(num_features, len(train_data)):
    X_train.append(train_data[i - num_features:i, 0])
    y_train.append(train_data[i, 0])
    if i <= num_features:
        print(f"X_train = {X_train}, y_train = {y_train}")
# Out:
# X_train = [array([0.15810341, 0.17824067, 0.18204077, 0.18421805, 0.21377377,
#        0.2154748 , 0.20117374, 0.18177691, 0.17396307, 0.18184765,
#        0.15590762, 0.16370109, 0.17100882, 0.15958038, 0.16059011,
#        0.11954266, 0.12092323, 0.12050622, 0.12848285, 0.14908424,
#        0.12933834, 0.11736662, 0.11797504, 0.12653942, 0.12382275,
#        0.12248137, 0.12873194, 0.1347796 , 0.12500025, 0.10924181,
#        0.10998178, 0.09349115, 0.08802594, 0.09310927, 0.07732502,
#        0.05796971, 0.0690427 , 0.06821645, 0.07109326, 0.08508553,
#        0.08275416, 0.07544472, 0.08849193, 0.08284621, 0.09699691,
#        0.10555024, 0.10803632, 0.12171248, 0.11151068, 0.12347648,
#        0.12422266, 0.11235295, 0.10261076, 0.10758634, 0.10079888,
#        0.09917388, 0.11058662, 0.11439667, 0.11062953, 0.11985364,
#        0.12170393, 0.12831959, 0.12910511, 0.12815664, 0.11668917,
#        0.10414946, 0.0942238 , 0.09352971, 0.08642738, 0.09829647,
#        0.09204232, 0.09233246, 0.07709475, 0.07819839, 0.07849413,
#        0.07172734, 0.07740556, 0.08378068, 0.08860046, 0.08821206])], y_train = [0.08569161572787061]

# %%
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (1516, 80)

# %%
# Reshape the data
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_train.shape
# Out:
# (1516, 80, 1)

# %% [markdown]
# ### Model Training

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.utils import plot_model

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences = True, input_shape = (X_train.shape[1], 1), name = "LSTM_layer1"))
model.add(LSTM(50, return_sequences = False, name = "LSTM_layer2"))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  LSTM_layer1 (LSTM)          (None, 80, 50)            10400
#
#  LSTM_layer2 (LSTM)          (None, 50)                20200
#
#  dense (Dense)               (None, 25)                1275
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 31,901
# Trainable params: 31,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\kaleem\appdata\local\programs\python\python310\lib\site-packages (0.20.1)

# %%
tf.keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# Compile the model
model.compile(optimizer = "adam", loss = "mean_squared_error")

# %%
model.fit(X_train, y_train, batch_size = 1, epochs = 50)
# Out:
# Epoch 1/50
# 1516/1516 [==============================] - 72s 45ms/step - loss: 0.0030
# Epoch 2/50
# 1516/1516 [==============================] - 56s 37ms/step - loss: 0.0011
# Epoch 3/50
# 1516/1516 [==============================] - 58s 38ms/step - loss: 9.0129e-04
# Epoch 4/50
# 1516/1516 [==============================] - 54s 36ms/step - loss: 6.5540e-04
# Epoch 5/50
# 1516/1516 [==============================] - 59s 39ms/step - loss: 7.4544e-04
# Epoch 6/50
# 1516/1516 [==============================] - 61s 40ms/step - loss: 4.4740e-04
# Epoch 39/50
# 1516/1516 [==============================] - 61s 40ms/step - loss: 3.9975e-04
# Epoch 40/50
# 1516/1516 [==============================] - 54s 36ms/step - loss: 4.2741e-04
# Epoch 41/50
# 1516/1516 [==============================] - 58s 38ms/step - loss: 3.8556e-04
# Epoch 42/50
# 1516/1516 [==============================] - 42s 28ms/step - loss: 3.7445e-04
# Epoch 43/50
# 1516/1516 [==============================] - 40s 26ms/step - loss: 3.9039e-04
# Epoch 44/50
# 1516/1516 [==============================] - 40s 27ms/step - loss: 4.3541e-04
# Epoch 45/50
# 1516/1516 [==============================] - 42s 28ms/step - loss: 3.8578e-04
# Epoch 46/50
# 1516/1516 [==============================] - 37s 24ms/step - loss: 3.8687e-04
# Epoch 47/50
# 1516/1516 [==============================] - 37s 24ms/step - loss: 4.2531e-04
# Epoch 48/50
# 1516/1516 [==============================] - 38s 25ms/step - loss: 3.8591e-04
# Epoch 49/50
# 1516/1516 [==============================] - 40s 27ms/step - loss: 3.8841e-04
# Epoch 50/50
# 1516/1516 [==============================] - 41s 27ms/step - loss: 3.7827e-04

# %% [markdown]
# ### Testing the model

# %% [markdown]
# Create test dataset

# %%
test_data = scaled_data[training_data_len - num_features:, :]

# %%
test_data.shape
# Out:
# (478, 1)

# %% [markdown]
# Create X_test and y_test

# %%
X_test = []
y_test = dataset[training_data_len:, :]

for i in range(num_features, len(test_data)):
    X_test.append(test_data[i - num_features: i, 0])

# %%
X_test = np.array(X_test)

# %%
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_test.shape
# Out:
# (398, 80, 1)

# %% [markdown]
# Predicting values for test data

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 13/13 [==============================] - 1s 22ms/step

# %%
predictions[:5], y_test[:5]
# Out:
# (array([[31487.15 ],
#         [30337.652],
#         [30701.904],
#         [29106.49 ],
#         [30381.219]], dtype=float32),
#  array([[29874.01],
#         [30444.93],
#         [28715.32],
#         [30319.23],
#         [29201.01]]))

# %%
y_test.shape, predictions.shape
# Out:
# ((398, 1), (398, 1))

# %% [markdown]
# Root Mean Squared Error(RMSE)

# %%
rmse = np.sqrt(np.mean((y_test - predictions) ** 2))
rmse
# Out:
# 749.6699936756279

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, predictions)
# Out:
# 562005.099417616

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid["Predictions"] = predictions
# Out:
# C:\Users\kaleem\AppData\Local\Temp\ipykernel_27736\2096051634.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["Predictions"] = predictions

# %%
plt.figure(figsize = (16, 8))
plt.title("Splitting the data")
plt.xlabel("Date", fontsize = 18)
plt.ylabel("BitCoin's Close Price", fontsize = 18)
plt.plot(train["Close"])
plt.plot(valid[["Close"]])
plt.legend(["Train", "Test"], loc = "lower right")
plt.savefig('split.png', dpi=300)
plt.show()

# %%
plt.figure(figsize = (16, 8))
plt.title("Model")
plt.xlabel("Date", fontsize = 18)
plt.ylabel("BitCoin's Close Price", fontsize = 18)
plt.plot(train["Close"])
plt.plot(valid[["Close", "Predictions"]])
plt.legend(["Train", "Val", "Predictions"], loc = "lower right")
plt.show()
